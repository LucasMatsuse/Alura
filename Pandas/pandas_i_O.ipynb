# %%
import pandas as pd
import sqlalchemy

# %%
sqlalchemy.__version__
# Out:
# '1.4.49'

# %%
pip install --upgrade 'sqlalchemy<2.0'
# Out:
# Collecting sqlalchemy<2.0
#   Downloading SQLAlchemy-1.4.49-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy<2.0) (2.0.2)
# Installing collected packages: sqlalchemy
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.20
#     Uninstalling SQLAlchemy-2.0.20:
#       Successfully uninstalled SQLAlchemy-2.0.20
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.49 which is incompatible.
# Successfully installed sqlalchemy-1.4.49

# %%
sqlalchemy.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9163e6938f51> in <cell line: 1>()
# ----> 1 sqlalchemy.__version__
#
# NameError: name 'sqlalchemy' is not defined

# %% [markdown]
# # Aula 1 (csv)

# %%
urlaula1 = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/superstore_data.csv'
dados_mercado = pd.read_csv(urlaula1,usecols=['Id', 'Year_Birth', 'Income'])

# %%
dados_mercado
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# quando importamos um arquivo com o pandas pode acontecer dele não estar na mesma codificação usada como default(UTF-8) e aparecerá o erro **UnicodeDecodeError**.
# Para descobrir qual é a codificação do arquivo podemos utiliza o seguinte método:
#
# import chardet
#
# with open('caminho do arquivo', 'rb') as file:
#
#       print(chardet.detect(file.read()))
# e o resultado seria por exemplo:
#
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}
#
# isso mostra que a codificação usada no arquivo é a ISO-8859-1 com 73% de certeza,
# então na hora de ler o arquivo podemos fazer:
#
# df = pd.read_csv('url', encoding='ISO-8859-1')

# %% [markdown]
# # aula 2 (Planilha)

# %%
'''
a url original acaba depois do .xlsx mas não seria possivel usar direto pois o arquivo é muito grande para abrir pelo github
então adicionamos ?raw=True ao final dela para abrir o arquivo pela url. Outra opção é baixar o arquivo para o PC.
'''
urlaula2 = 'https://github.com/alura-cursos/Pandas/blob/main/emissoes_CO2.xlsx?raw=True'

# %%
dados_co2 = pd.read_excel(urlaula2)

# %%
dados_co2
# Out:
#               País ISO 3166-1 alpha-3   Ano         Total        Carvão  \
# 0      Afeganistão                AFG  1750  0.000000e+00           NaN
# 1      Afeganistão                AFG  1751  0.000000e+00           NaN
# 2      Afeganistão                AFG  1752  0.000000e+00           NaN
# 3      Afeganistão                AFG  1753  0.000000e+00           NaN
# 4      Afeganistão                AFG  1754  0.000000e+00           NaN
# ...            ...                ...   ...           ...           ...
# 63099       Global                WLD  2017  3.609674e+10  1.450697e+10
# 63100       Global                WLD  2018  3.682651e+10  1.474683e+10
# 63101       Global                WLD  2019  3.708256e+10  1.472598e+10
# 63102       Global                WLD  2020  3.526409e+10  1.417456e+10
# 63103       Global                WLD  2021  3.712385e+10  1.497960e+10
#
#                Oléo           Gás       Cimento       Queima        Outro  \
# 0               NaN           NaN           NaN          NaN          NaN
# 1               NaN           NaN           NaN          NaN          NaN
# 2               NaN           NaN           NaN          NaN          NaN
# 3               NaN           NaN           NaN          NaN          NaN
# 4               NaN           NaN           NaN          NaN          NaN
# ...             ...           ...           ...          ...          ...
# 63099  1.224263e+10  7.144928e+09  1.507923e+09  391992176.0  302294047.0
# 63100  1.226602e+10  7.529847e+09  1.569218e+09  412115746.0  302478706.0
# 63101  1.234565e+10  7.647528e+09  1.617507e+09  439253991.0  306638573.0
# 63102  1.119181e+10  7.556290e+09  1.637538e+09  407583673.0  296301685.0
# 63103  1.183716e+10  7.921829e+09  1.672592e+09  416525563.0  296145746.0
#
#        Per Capita
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 63099   4749682.0
# 63100   4792753.0
# 63101   4775633.0
# 63102   4497423.0
# 63103   4693699.0
#
# [63104 rows x 11 columns]

# %%
# usado para saber se a planilha tem mais de uma pagina e saber os nomes.
pd.ExcelFile(urlaula2).sheet_names
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-1f3d63d6a7f7> in <cell line: 2>()
#       1 # usado para saber se a planilha tem mais de uma pagina e saber os nomes.
# ----> 2 pd.ExcelFile(urlaula2).sheet_names
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1693         self.storage_options = storage_options
#    1694
# -> 1695         self._reader = self._engines[engine](self._io, storage_options=storage_options)
#    1696
#    1697     def __fspath__(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_openpyxl.py in __init__(self, filepath_or_buffer, storage_options)
#     555         """
#     556         import_optional_dependency("openpyxl")
# --> 557         super().__init__(filepath_or_buffer, storage_options=storage_options)
#     558
#     559     @property
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __init__(self, filepath_or_buffer, storage_options)
#     543             self.handles.handle.seek(0)
#     544             try:
# --> 545                 self.book = self.load_workbook(self.handles.handle)
#     546             except Exception:
#     547                 self.close()
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_openpyxl.py in load_workbook(self, filepath_or_buffer)
#     566         from openpyxl import load_workbook
#     567
# --> 568         return load_workbook(
#     569             filepath_or_buffer, read_only=True, data_only=True, keep_links=False
#     570         )
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/reader/excel.py in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     344     reader = ExcelReader(filename, read_only, keep_vba,
#     345                          data_only, keep_links, rich_text)
# --> 346     reader.read()
#     347     return reader.wb
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/reader/excel.py in read(self)
#     299             apply_stylesheet(self.archive, self.wb)
#     300             action = "read worksheets"
# --> 301             self.read_worksheets()
#     302             action = "assign names"
#     303             self.parser.assign_names()
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/reader/excel.py in read_worksheets(self)
#     226
#     227             if self.read_only:
# --> 228                 ws = ReadOnlyWorksheet(self.wb, sheet.name, rel.target, self.shared_strings)
#     229                 ws.sheet_state = sheet.state
#     230                 self.wb._sheets.append(ws)
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_read_only.py in __init__(self, parent_workbook, title, worksheet_path, shared_strings)
#      40         self._worksheet_path = worksheet_path
#      41         self._shared_strings = shared_strings
# ---> 42         self._get_size()
#      43         self.defined_names = DefinedNameDict()
#      44
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_read_only.py in _get_size(self)
#      47         src = self._get_source()
#      48         parser = WorkSheetParser(src, [])
# ---> 49         dimensions = parser.parse_dimensions()
#      50         src.close()
#      51         if dimensions is not None:
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py in parse_dimensions(self)
#     176         it = iterparse(self.source)
#     177
# --> 178         for _event, element in it:
#     179             if element.tag == DIMENSION_TAG:
#     180                 dim = SheetDimension.from_tree(element)
#
# /usr/lib/python3.10/xml/etree/ElementTree.py in iterator(source)
#    1251             yield None
#    1252             while True:
# -> 1253                 yield from pullparser.read_events()
#    1254                 # load event buffer
#    1255                 data = source.read(16 * 1024)
#
# /usr/lib/python3.10/xml/etree/ElementTree.py in read_events(self)
#    1320         events = self._events_queue
#    1321         while events:
# -> 1322             event = events.popleft()
#    1323             if isinstance(event, Exception):
#    1324                 raise event
#
# KeyboardInterrupt:

# %%
percapita = pd.read_excel(urlaula2,sheet_name='emissoes_percapita')

# %%
percapita

# %%
intervalo = pd.read_excel(urlaula2,sheet_name='emissoes_C02',usecols='A:D')

# %%
intervalo

# %%
linhas = pd.read_excel(urlaula2,sheet_name='emissoes_C02',usecols='A:D',nrows=10)

# %%
linhas

# %%
linhas.to_excel('AFG1750_1759.xlsx',index=False)

# %% [markdown]
# ## Google planilhas

# %%
# o parametro /gviz/tq depois das chaves chama a API de interação entre o colab e o planilhas, ?tqx=out:csv indica o formato que eu quero e o &sheet diz que eu quero a planilha toda(cabeçalho,formatação...)
sheet_id = '1NdwzuE_wXFgLU2WVwxn911_0uQhTnDIV2F52OnY_0fI'

url_sheets = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

# %%
sheet = pd.read_csv(url_sheets)

# %%
sheet.head()

# %%
# também é possivel passar o nome da planilha que vc quer importar
sheet_name = 'emissoes_CO2'
url_sheets1 = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
sheet2 = pd.read_csv(url_sheets1)

# %%
sheet2.head()

# %% [markdown]
# # Aula 3 (JSON)

# %%
# arquivo json sem informações aninhadas
pacientes = pd.read_json('/content/pacientes.json')

# %%
pacientes.head()

# %%
# arquivo com informações aninhadas
pacientes2 = pd.read_json('/content/pacientes_2.json')

# %%
pacientes2.head()

# %%
'''
Normaliza os dados do arquino na coluna escolhida, ou seja desfaz o aninhamento
O json_normaliza aceita somente dicionarios ou lista de dicionarios por isso usamos o pacientes2['Pacientes'] como parametro
'''
pacientes2_normalizado = pd.json_normalize(pacientes2['Pacientes'])

# %%
pacientes2_normalizado

# %%
'''Para normalizar o arquivo json sem escolher só a bilioteca precisamos fazer o seguinte procedimento'''
#Importando o módulo JSON
import json

#Lendo o arquivo json usando o módulo Python JSON
with open('/content/pacientes_2.json','r') as f:
    dados = json.loads(f.read())

#Normalizando os dados com os parâmetros record_path e meta
pd.json_normalize(dados, record_path='Pacientes', meta=['Pesquisa', 'Ano'])

# %%
# copia dos dados do arquivo pacientes2 obtidos com o json crack
dados_dict = {
  "Pesquisa": "Principais Indicadores de Doenca Cardiaca",
  "Ano": 2020,
  "Pacientes": [
    {
      "ID": "01",
      "Faixa_etaria": "55-59",
      "Sexo_biologico": "Feminino",
      "Raça": "Branca",
      "IMC": 16.6,
      "Fumante": "Sim",
      "Consumo_alcool": "Nao",
      "Saude_fisica": 3,
      "Saude_mental": 30,
      "Dificuldade_caminhar": "Nao",
      "Atividade_fisica": "Sim",
      "Saude_geral": "Muito boa",
      "Horas_sono": 5,
      "Problemas_saude": [
        "Diabetes",
        "Asma",
        "Cancer_pele"
      ]
    },
    {
      "ID": "02",
      "Faixa_etaria": "80 ou +",
      "Sexo_biologico": "Feminino",
      "Raça": "Branca",
      "IMC": 20.34,
      "Fumante": "Nao",
      "Consumo_alcool": "Nao",
      "Saude_fisica": 0,
      "Saude_mental": 0,
      "Dificuldade_caminhar": "Nao",
      "Atividade_fisica": "Sim",
      "Saude_geral": "Muito boa",
      "Horas_sono": 7,
      "Problemas_saude": [
        "AVC"
      ]
    },
    {
      "ID": "03",
      "Faixa_etaria": "65-69",
      "Sexo_biologico": "Masculino",
      "Raça": "Branca",
      "IMC": 26.58,
      "Fumante": "Sim",
      "Consumo_alcool": "Nao",
      "Saude_fisica": 20,
      "Saude_mental": 30,
      "Dificuldade_caminhar": "Nao",
      "Atividade_fisica": "Sim",
      "Saude_geral": "Muito boa",
      "Horas_sono": 8,
      "Problemas_saude": [
        "diabetes",
        "Asma"
      ]
    }
  ]
}

# %%
#o pârametro record_path tem a msm função indicar qual coluna será normalizada e o pârametro meta inclui as colunas pesquisa e ano no dt
pacientes2_normalizado = pd.json_normalize(dados_dict, record_path =['Pacientes'], meta=['Pesquisa', 'Ano'])

# %%
pacientes2_normalizado.to_json('historico_pacientes.json')

# %% [markdown]
# ## Obter dados de API's

# %%
import requests
import json

# %%
# a url original acaba .com/ o resto é usado para acessar os resultados
dados_frutas = requests.get('https://fruityvice.com/api/fruit/all')

# %%
#recuperando os resultados do api, é preciso passar o atributo.text
resultado = json.loads(dados_frutas.text)

# %%
df_resultado = pd.DataFrame(resultado)

# %% [markdown]
# # aula 4(html e xml)

# %% [markdown]
# ## html

# %%
dados_html = pd.read_html('/content/filmes_wikipedia.html')

# %%
# a leitura de html mostra as tabela no formato de lista.
dados_html

# %%
type(dados_html)

# %%
len(dados_html)

# %%
#para visualizar os dt na lista é preciso chama-los pelo indice da lista
top_filmes = dados_html[1]

# %%
top_filmes

# %%
top_filmes.to_html('top_filmes.html')

# %%
top_filmes.to_csv('top_filmes.csv',index=False)

# %% [markdown]
# ## xml

# %%
top_imdb = pd.read_xml('/content/imdb_top_1000.xml')

# %%
top_imdb

# %% [markdown]
# # aula 5 (banco de dados)

# %% [markdown]
# Bancos de dados são sistemas que permitem o armazenamento, organização e recuperação de informações de forma estruturada e eficiente. Eles são amplamente utilizados em muitas áreas, desde gerenciamento de negócios à pesquisa científica. Um banco de dados bem projetado pode melhorar significativamente a eficiência e a precisão das operações de uma organização.
#
# Existem bancos de dados relacionais e não-relacionais. Os bancos de dados relacionais representam e armazenam dados em tabelas. Já os não-relacionais, também conhecidos como bancos de dados NoSQL (Not Only SQL - Não SQL), usam uma variedade de estruturas de dados, como documentos, grafos ou pares de chave-valor.
#
# Python oferece vários pacotes e bibliotecas para trabalhar com bancos de dados, incluindo SQLite, MySQL, PostgreSQL, Oracle, MongoDB, entre outros. Um dos pacotes mais comuns usados para trabalhar com bancos de dados relacionais em Python é o pacote sqlite3 que oferece suporte a bancos de dados SQLite. Este banco de dados é leve e incorporado que não exige um servidor separado para ser executado que já vem nativamente instalado no Google Colab.
#
# Para trabalhar com esse banco podemos utilizar a SQLAlchemy, uma biblioteca de mapeamento objeto-relacional (ORM), que possibilita interagir com bancos de dados relacionais usando código Python. Ela fornece uma camada de abstração que permite aos desenvolvedores trabalhar com objetos Python em vez de lidar diretamente com as complexidades da linguagem SQL (Structured Query Language - Linguagem de consulta estruturada).
#
# Uma das principais vantagens do uso de SQLAchemy é a capacidade de criar código mais legível e fácil de manter. Com SQLAlchemy, as operações do banco de dados são executadas usando métodos em objetos Python, tornando o código mais claro e menos propenso a erros.
#
# Além disso, a SQLAlchemy oferece suporte a consultas complexas em bancos de dados, permitindo que pessoas desenvolvedoras extraiam facilmente informações relevantes de grandes conjuntos de dados. Isso é especialmente útil em aplicações que precisam lidar com grandes quantidades de dados.
#
# https://www.sqlalchemy.org/

# %%
from sqlalchemy import create_engine , MetaData , Table, inspect

# %%
engine = create_engine('sqlite:///:memory:')
# sqlite é o banco de dados nativo do colab, e o memory indica que usaremos um banco de dados local

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/clientes_banco.csv'

# %%
dados = pd.read_csv(url)

# %%
dados.head()
# Out:
#    ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0     5008804     32   Ensino superior  União-estável                2
# 1     5008805     32   Ensino superior  União-estável                2
# 2     5008806     58      Ensino médio         Casado                2
# 3     5008808     52      Ensino médio       Solteiro                1
# 4     5008809     52      Ensino médio       Solteiro                1
#
#     Categoria_de_renda   Ocupacao  Anos_empregado  Rendimento_anual  \
# 0            Empregado      Outro              12          427500.0
# 1            Empregado      Outro              12          427500.0
# 2            Empregado  Segurança               3          112500.0
# 3  Associado comercial     Vendas               8          270000.0
# 4  Associado comercial     Vendas               8          270000.0
#
#    Tem_carro                   Moradia
# 0          1       Apartamento alugado
# 1          1       Apartamento alugado
# 2          1  Casa/apartamento próprio
# 3          0  Casa/apartamento próprio
# 4          0  Casa/apartamento próprio

# %%
dados.to_sql('clientes',engine,index=False)
# Out:
# 438463

# %%
inspector = inspect(engine)

# %%
print(inspector.get_table_names())
# Out:
# ['clientes', 'clientes_empregados']

# %% [markdown]
# SQL (Structured Query Language - Linguagem de consulta estruturada) é uma linguagem de consulta utilizada em bancos de dados relacionais para inserir, atualizar, consultar e gerenciar dados.
#
# Para fazer tudo isso,existem as cláusulas SQL, que são componentes fundamentais das instruções SQL, permitindo especificar detalhes sobre como a consulta ou a operação de banco de dados devem ser executadas. As cláusulas são usadas para filtrar, classificar, agrupar e limitar os resultados das consultas.
#
# As instruções SQL podem ser compostas por uma ou mais cláusulas que fornecem informações adicionais sobre o que a consulta deve fazer. As cláusulas mais comuns são:
#
# SELECT: especifica quais colunas devem ser selecionadas na consulta.
# FROM: especifica as tabelas do banco de dados que devem ser consultadas.
# WHERE: filtra os resultados da consulta com base em uma ou mais condições especificadas.
# ORDER BY: classifica os resultados da consulta em ordem crescente ou decrescente com base em uma ou mais colunas.
# GROUP BY: agrupa os resultados da consulta com base em uma ou mais colunas.
# LIMIT: limita o número de linhas retornadas pelos resultados da consulta.
# Temos um exemplo simples de sintaxe SQL que usa o comando SELECT para consultar dados de uma tabela de colaboradores(as) em um banco de dados:
#
#     SELECT nome, sobrenome, salario
#     FROM colaboradores
#     WHERE departamento = 'vendas'
#
# Nessa instrução SQL, a cláusula SELECT é usada para especificar as colunas que se deseja consultar da tabela "colaboradores", incluindo "nome", "sobrenome" e "salario". A cláusula FROM é usada para especificar a tabela que se deseja consultar, que é "colaboradores" neste caso.
#
# A cláusula WHERE é usada para filtrar os resultados da consulta com base em uma condição especificada. Neste exemplo, a condição é departamento = 'vendas', o que significa que a consulta retornará apenas as pessoas colaboradoras que trabalham no departamento de vendas.
#
# No próximo vídeo vamos aprender a usar algumas dessas cláusulas para realizar as primeiras consultas SQL na tabela que contém os dados de clientes de uma instituição financeira.

# %%
query = 'SELECT * FROM clientes WHERE Categoria_de_renda = "Empregado"'

# %%
empregados = pd.read_sql(query,engine)

# %%
empregados.to_sql('clientes_empregados',con=engine,index=False)
# Out:
# 226059

# %%
pd.read_sql_table('clientes_empregados', engine, columns=['ID_Cliente', 'Grau_escolaridade', 'Rendimento_anual'])
# Out:
#         ID_Cliente Grau_escolaridade  Rendimento_anual
# 0          5008804   Ensino superior          427500.0
# 1          5008805   Ensino superior          427500.0
# 2          5008806      Ensino médio          112500.0
# 3          5008815   Ensino superior          270000.0
# 4          5112956   Ensino superior          270000.0
# ...            ...               ...               ...
# 226054     6837905      Ensino médio          355050.0
# 226055     6837906      Ensino médio          355050.0
# 226056     6839936      Ensino médio          135000.0
# 226057     6840222      Ensino médio          103500.0
# 226058     6842885      Ensino médio          121500.0
#
# [226059 rows x 3 columns]

# %%
query = 'SELECT * FROM clientes'

# %%
pd.read_sql(query,engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008809     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6840104     62      Ensino médio     Divorciado                1
# 438459     6840222     43      Ensino médio       Solteiro                1
# 438460     6841878     22   Ensino superior       Solteiro                1
# 438461     6842765     59      Ensino médio         Casado                2
# 438462     6842885     51      Ensino médio         Casado                2
#
#          Categoria_de_renda          Ocupacao  Anos_empregado  \
# 0                 Empregado             Outro              12
# 1                 Empregado             Outro              12
# 2                 Empregado         Segurança               3
# 3       Associado comercial            Vendas               8
# 4       Associado comercial            Vendas               8
# ...                     ...               ...             ...
# 438458          Pensionista             Outro               0
# 438459            Empregado  Construção Civil               8
# 438460  Associado comercial            Vendas               1
# 438461          Pensionista             Outro               0
# 438462            Empregado            Vendas               3
#
#         Rendimento_anual  Tem_carro                   Moradia
# 0               427500.0          1       Apartamento alugado
# 1               427500.0          1       Apartamento alugado
# 2               112500.0          1  Casa/apartamento próprio
# 3               270000.0          0  Casa/apartamento próprio
# 4               270000.0          0  Casa/apartamento próprio
# ...                  ...        ...                       ...
# 438458          135000.0          0  Casa/apartamento próprio
# 438459          103500.0          0  Casa/apartamento próprio
# 438460           54000.0          0          Mora com os pais
# 438461           72000.0          0  Casa/apartamento próprio
# 438462          121500.0          0  Casa/apartamento próprio
#
# [438463 rows x 11 columns]

# %%
query = 'DELETE FROM clientes WHERE ID_Cliente = 5008804'
with engine.connect() as conn:
  conn.execute(query)

# %%
pd.read_sql_table('clientes', engine)

# %%
query = 'UPDATE clientes  SET Grau_escolaridade = "Ensino Superior" WHERE ID_Cliente = 5008806'
with engine.connect() as conn:
  conn.execute(query)

# %%
pd.read_sql_table('clientes',engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008805     32   Ensino superior  União-estável                2
# 1          5008806     58   Ensino Superior         Casado                2
# 2          5008808     52      Ensino médio       Solteiro                1
# 3          5008809     52      Ensino médio       Solteiro                1
# 4          5008810     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438457     6840104     62      Ensino médio     Divorciado                1
# 438458     6840222     43      Ensino médio       Solteiro                1
# 438459     6841878     22   Ensino superior       Solteiro                1
# 438460     6842765     59      Ensino médio         Casado                2
# 438461     6842885     51      Ensino médio         Casado                2
#
#          Categoria_de_renda          Ocupacao  Anos_empregado  \
# 0                 Empregado             Outro              12
# 1                 Empregado         Segurança               3
# 2       Associado comercial            Vendas               8
# 3       Associado comercial            Vendas               8
# 4       Associado comercial            Vendas               8
# ...                     ...               ...             ...
# 438457          Pensionista             Outro               0
# 438458            Empregado  Construção Civil               8
# 438459  Associado comercial            Vendas               1
# 438460          Pensionista             Outro               0
# 438461            Empregado            Vendas               3
#
#         Rendimento_anual  Tem_carro                   Moradia
# 0               427500.0          1       Apartamento alugado
# 1               112500.0          1  Casa/apartamento próprio
# 2               270000.0          0  Casa/apartamento próprio
# 3               270000.0          0  Casa/apartamento próprio
# 4               270000.0          0  Casa/apartamento próprio
# ...                  ...        ...                       ...
# 438457          135000.0          0  Casa/apartamento próprio
# 438458          103500.0          0  Casa/apartamento próprio
# 438459           54000.0          0          Mora com os pais
# 438460           72000.0          0  Casa/apartamento próprio
# 438461          121500.0          0  Casa/apartamento próprio
#
# [438462 rows x 11 columns]
